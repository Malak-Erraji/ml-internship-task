# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Malak-Erraji/ml-internship-task/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I'm choosing **Lane 1: Ranking Signal Analysis**.
#
# I want to start by understanding which observable content and search signals
# are actually associated with strong or weak search performance, before
# committing to a specific scoring or clustering model. This lane lets me
# explore the data broadly first — looking at correlations and grouped
# patterns — rather than locking into one output shape immediately. It's also
# a natural extension of the starter notebooks I already ran, which showed
# that a learned model can meaningfully beat a hand-written rule; I want to
# understand *why*, by looking at which signals actually carry information.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# What decision does your work improve?
# Not a single-page decision — Lane 1 is about a broader strategic decision: which types of content traits are worth paying attention to at all.
# Who acts on it?
# A content strategist or SEO lead, deciding where to focus a content refresh initiative across a whole site or portfolio of clients.
# What does a wrong recommendation cost?*
# If I claim a signal matters when it's actually just noise or coincidence (e.g. 'short pages always underperform'), the team might spend weeks rewriting content that was never the actual problem — burning editorial hours while the real issue (e.g. poor position, technical SEO) goes unaddressed

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os
if not os.path.exists('ml-internship-task'):
    # !git clone https://github.com/Malak-Erraji/ml-internship-task.git
# %cd ml-internship-task
import pandas as pd
df = pd.read_csv('data/raw/content_refresh_anonymized.csv')
print("Total pages :", len(df) )
print("Pages with trend_direction == 'down':", (df['trend_direction'] == 'down').sum())
print("Pages with impressions_90d >= 500:", (df['impressions_90d'] >= 500).sum())
# Out:
# Cloning into 'ml-internship-task'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 116 (delta 32), reused 103 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (116/116), 1.82 MiB | 12.75 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/ml-internship-task/ml-internship-task/ml-internship-task
# Total pages : 30000
# Pages with trend_direction == 'down': 16262
# Pages with impressions_90d >= 500: 16726

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can claim:** Observed associations between page traits (age,
# freshness, word count, position, etc.) and performance outcomes within
# this anonymized dataset, described as "observed" or "associated with" —
# not proven causes.
#
# **What I cannot claim:**
# - That any signal is a genuine Google ranking factor.
# - That correlation implies causation (e.g. longer pages ≠ longer pages
#   cause better rankings).
# - Anything about specific real clients, domains, or URLs — all identifiers
#   are pseudonymized.
# - That my findings generalize beyond this data snapshot to the full
#   warehouse without re-checking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
